# %% [markdown]
# Tratamento de texto - Pagina Web

# %%
import nltk
nltk.download('punkt')
import urllib.request
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %% [markdown]
# Os sites são escritos em HTML; portanto, quando você extrai informações diretamente de um site, você recebe todo o código de volta junto com o texto.

# %%
url = "https://en.wikipedia.org/wiki/Python_(programming_language)"

# %% [markdown]
# Fazendo a requisição na pagina

# %%
response = urllib.request.urlopen(url)

# %% [markdown]
# Lendo a informação

# %%
html = response.read()

# %% [markdown]
# Exibindo os 1000 primeiros caracteres

# %%
html[:1000]
# Out:
# b'<!DOCTYPE html>\n<html class="client-nojs" lang="en" dir="ltr">\n<head>\n<meta charset="UTF-8"/>\n<title>Python (programming language) - Wikipedia</title>\n<script>document.documentElement.className="client-js";RLCONF={"wgBreakFrames":!1,"wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgMonthNamesShort":["","Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec"],"wgRequestId":"XfxyhwpAICMAAEVUOKYAAAAU","wgCSPNonce":!1,"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":!1,"wgNamespaceNumber":0,"wgPageName":"Python_(programming_language)","wgTitle":"Python (programming language)","wgCurRevisionId":931599903,"wgRevisionId":931599903,"wgArticleId":23862,"wgIsArticle":!0,"wgIsRedirect":!1,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["Articles with short description","Use '

# %% [markdown]
# Usaremos uma biblioteca Python chamada **BeautifulSoup** para facilitar o trabalho com o HTML.

# %%
from bs4 import BeautifulSoup

# %%
soup = BeautifulSoup(html, "html5lib")

# %% [markdown]
# A Wikipedia coloca o texto mais legível nas tags de parágrafo ou "p".

# %%
web_paragraph = []
for p_tag in soup.find_all('p'):
  web_paragraph.append(p_tag.text)

# %%
len(web_paragraph)
# Out:
# 83

# %%
web_tokens = [nltk.word_tokenize(paragraph) for paragraph in web_paragraph]

# %%
web_tokens[2]
# Out:
# ['Python',
#  'is',
#  'dynamically',
#  'typed',
#  'and',
#  'garbage-collected',
#  '.',
#  'It',
#  'supports',
#  'multiple',
#  'programming',
#  'paradigms',
#  ',',
#  'including',
#  'procedural',
#  ',',
#  'object-oriented',
#  ',',
#  'and',
#  'functional',
#  'programming',
#  '.',
#  'Python',
#  'is',
#  'often',
#  'described',
#  'as',
#  'a',
#  '``',
#  'batteries',
#  'included',
#  "''",
#  'language',
#  'due',
#  'to',
#  'its',
#  'comprehensive',
#  'standard',
#  'library',
#  '.',
#  '[',
#  '28',
#  ']']
